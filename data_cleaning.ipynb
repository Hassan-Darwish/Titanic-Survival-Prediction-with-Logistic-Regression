# %%
import numpy as np
import pandas as pd

# %%
training_set = pd.read_csv('train.csv')
testing_set = pd.read_csv('test.csv')
gender_set = pd.read_csv('gender_submission.csv')

# %%
training_set.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
training_set['FamilySize'] = training_set['SibSp'] + training_set['Parch'] + 1
testing_set['FamilySize'] = testing_set['SibSp'] + testing_set['Parch'] + 1

# %%
training_set.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
training_set.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
training_set['Age'].fillna(training_set['Age'].median(), inplace=True)
testing_set['Age'].fillna(testing_set['Age'].median(),inplace=True)

# %%
testing_set[testing_set['Fare'].isna()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked  FamilySize
# 152   NaN   NaN        S           1

# %%
testing_set['Fare'].fillna(testing_set[testing_set['Pclass'] == 3]['Fare'].median(), inplace=True)

# %%
testing_set.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
training_set['Embarked'].fillna(training_set['Embarked'].mode()[0], inplace=True)

# %%
training_set.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
for series in (training_set,testing_set):
    series.drop(['Name', 'Ticket', 'SibSp', 'Parch', 'Cabin'], axis=1,inplace=True)

# %%
training_set = pd.get_dummies(training_set,columns=['Embarked'])
testing_set = pd.get_dummies(testing_set,columns=['Embarked'])

# %%
for series in (training_set, testing_set):
    series['Sex'] = series['Sex'].map({"female" : 0, "male" : 1})

# %%
training_set.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age     Fare  FamilySize  Embarked_C  \
# 0            1         0       3    1  22.0   7.2500           2           0
# 1            2         1       1    0  38.0  71.2833           2           1
# 2            3         1       3    0  26.0   7.9250           1           0
# 3            4         1       1    0  35.0  53.1000           2           0
# 4            5         0       3    1  35.0   8.0500           1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
for series in (training_set, testing_set):
    series['Pclass'] = (series['Pclass'] - series['Pclass'].min()) / (series['Pclass'].max() - series['Pclass'].min())
    series['Age'] = (series['Age'] - series['Age'].min()) / (series['Age'].max() - series['Age'].min())
    series['Fare'] = (series['Fare'] - series['Fare'].min()) / (series['Fare'].max() - series['Fare'].min())
    series['FamilySize'] = (series['FamilySize'] - series['FamilySize'].min()) / (series['FamilySize'].max() - series['FamilySize'].min())

# %%
training_set.head()
# Out:
#    PassengerId  Survived  Pclass  Sex       Age      Fare  FamilySize  \
# 0            1         0     1.0    1  0.271174  0.014151         0.1
# 1            2         1     0.0    0  0.472229  0.139136         0.1
# 2            3         1     1.0    0  0.321438  0.015469         0.0
# 3            4         1     0.0    0  0.434531  0.103644         0.1
# 4            5         0     1.0    1  0.434531  0.015713         0.0
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
training_set.to_csv('train_cleaned.csv', index=False)
testing_set.to_csv('test_cleaned.csv', index=False)
